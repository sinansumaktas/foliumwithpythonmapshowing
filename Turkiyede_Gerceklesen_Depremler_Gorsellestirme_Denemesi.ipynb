# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: requests in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sinan.sumaktas\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)

# %%
import folium
from folium import plugins
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time

# %%
import requests
from bs4 import BeautifulSoup

url="http://www.koeri.boun.edu.tr/scripts/lst9.asp"

sonuc=requests.get(url)
sonuc2=BeautifulSoup(sonuc.content,"lxml")
liste=[]
sonuc2=sonuc2.text
sonuc2=sonuc2.strip()
sonuc2=sonuc2.split("\r")

liste_enlem=[]
liste_boylam=[]
liste_yer=[]

for i in range(14,len(sonuc2)-20):
    i=sonuc2[i].split()
    if(len(i)>=9):
        liste_enlem.append(i[2])
        liste_boylam.append(i[3])
        liste_yer.append(str(i[8])+" "+str(i[9]))

# %%
df=pd.DataFrame({"Enlem":liste_enlem,"Boylam":liste_boylam,"Yer":liste_yer})

# %%
df.head()
# Out:
#      Enlem   Boylam                             Yer
# 0  36.8865  27.7772                  GOKOVA KORFEZI
# 1  39.5127  26.9127  TAYLIELI-BURHANIYE (BALIKESIR)
# 2  39.1948  36.1465          IKIZCE-GEMEREK (SIVAS)
# 3  38.1117  32.5012      BAGRIKURT-SELCUKLU (KONYA)
# 4  40.5975  28.8885       ESENKOY-CINARCIK (YALOVA)

# %%
df.dtypes
df["Enlem"]=df["Enlem"].astype("float64")
df["Boylam"]=df["Boylam"].astype("float64")

# %%
location=df[["Enlem","Boylam"]]

# %%
m= folium.Map(location=[40,32],zoom_start=7)
for i in range(0,len(df)):
    folium.CircleMarker(location=[df.iloc[i]['Enlem'], df.iloc[i]['Boylam']], popup=df.iloc[i]['Yer'], radius=15, fill_color='red',fill=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_701a23ead2ba682c4b82ad07c66e11d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_701a23ead2ba682c4b82ad07c66e11d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_701a23ead2ba682c4b82ad07c66e11d5 = L.map(
#                 &quot;map_701a23ead2ba682c4b82ad07c66e11d5&quot;,
#                 {
#                     center: [40.0, 32.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8741bc12c00651dac7c86125b851bc73 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_701a23ead2ba682c4b82ad07c66e11d5);
#
#
#             var circle_marker_5ac9d5b8db2ed35ec1ce68d46e7fc7fa = L.circleMarker(
#                 [36.8865, 27.7772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_701a23ead2ba682c4b82ad07c66e11d5);
#
#
#         var popup_33ae034d45fbbeb1869b4bc0514e3c5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dbac50902f0d218b6682bd67a9be7851 = $(`&lt;div id=&quot;html_dbac50902f0d218b6682bd67a9be7851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GOKOVA KORFEZI&lt;/div&gt;`)[0];
#             popup_33ae034d45fbbeb1869b4bc0514e3c5d.setContent(html_dbac50902f0d218b6682bd67a9be7851);
#
#
#         circle_marker_5ac9d5b8db2ed35ec1ce68d46e7fc7fa.bindPopup(popup_33ae034d45fbbeb1869b4bc0514e3c5d)
#         ;
#
#
#
#
#             var circle_marker_f5fe2119b966184f7bfc95d480f3519e = L.circleMarker(
#                 [39.5127, 26.9127],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_701a23ead2ba682c4b82ad07c66e11d5);
#
#
#         var popup_d200f2912d7fcaad630810a1f696c75c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d8b6bdf3dffabefe4372a5610fb30e1c = $(`&lt;div id=&quot;html_d8b6bdf3dffabefe4372a5610fb30e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TAYLIELI-BURHANIYE (BALIKESIR)&lt;/div&gt;`)[0];
#             popup_d200f2912d7fcaad630810a1f696c75c.setContent(html_d8b6bdf3dffabefe4372a5610fb30e1c);
#
#
#         circle_marker_f5fe2119b966184f7bfc95d480f3519e.bindPopup(popup_d200f2912d7fcaad630810a1f696c75c)
#         ;
#
#
#
#
#             var circle_marker_53a04c61dfcf0ec10c34489697980179 = L.circleMarker(
#                 [39.1948, 36.1465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_701a23ead2ba682c4b82ad07c66e11d5);
#
#
#         var popup_b962341916260be79ccd6dfbcd1dc30c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5ad620bae0396eded55d29111d81201b = $(`&lt;div id=&quot;html_5ad620bae0396eded55d29111d81201b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKIZCE-GEMEREK (SIVAS)&lt;/div&gt;`)[0];
#             popup_b962341916260be79ccd6dfbcd1dc30c.setContent(html_5ad620bae0396eded55d29111d81201b);
#
#
#         circle_marker_53a04c61dfcf0ec10c34489697980179.bindPopup(popup_b962341916260be79ccd6dfbcd1dc30c)
#         ;
#
#
#
#
#             var circle_marker_7d3a808e9978fff01e650a83ba9c8927 = L.circleMarker(
#                 [38.1117, 32.5012],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;rad

# %%
m= folium.Map(location=[41,30],zoom_start=8)
for i in range(0,len(df)):
    folium.Marker([df.iloc[i]['Enlem'], df.iloc[i]['Boylam']], popup=df.iloc[i]['Yer']).add_to(m)
    folium.CircleMarker(location=[df.iloc[i]['Enlem'],df.iloc[i]['Boylam']],radius=30, fill_color='red',fill=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8679f1bb0dbdaaba5ca7c70368aaecbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8679f1bb0dbdaaba5ca7c70368aaecbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8679f1bb0dbdaaba5ca7c70368aaecbe = L.map(
#                 &quot;map_8679f1bb0dbdaaba5ca7c70368aaecbe&quot;,
#                 {
#                     center: [41.0, 30.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61fbb4c3044fa29245e2cbf775e1cf7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#             var marker_133a3e31f502a1b59d6c8d554bd9bd28 = L.marker(
#                 [39.7287, 30.1263],
#                 {}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#         var popup_8c9bf3a034647557c158a1c5f32cf372 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ec09ed8dd1a5387e1a41b978577154ae = $(`&lt;div id=&quot;html_ec09ed8dd1a5387e1a41b978577154ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KUMBETAKPINAR-INONU (ESKISEHIR)&lt;/div&gt;`)[0];
#             popup_8c9bf3a034647557c158a1c5f32cf372.setContent(html_ec09ed8dd1a5387e1a41b978577154ae);
#
#
#         marker_133a3e31f502a1b59d6c8d554bd9bd28.bindPopup(popup_8c9bf3a034647557c158a1c5f32cf372)
#         ;
#
#
#
#
#             var circle_marker_3d9d1875124fc3fa4f02caf185179c8f = L.circleMarker(
#                 [39.7287, 30.1263],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#             var marker_031d0b72889343b695c3b7a930103e61 = L.marker(
#                 [38.9128, 29.1157],
#                 {}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#         var popup_d33e9c7dc462d3d4565b7bde0fde3539 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9ec4167d00c90c01c00f1515aff80b02 = $(`&lt;div id=&quot;html_9ec4167d00c90c01c00f1515aff80b02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TEPEKOY-PAZARLAR (KUTAHYA)&lt;/div&gt;`)[0];
#             popup_d33e9c7dc462d3d4565b7bde0fde3539.setContent(html_9ec4167d00c90c01c00f1515aff80b02);
#
#
#         marker_031d0b72889343b695c3b7a930103e61.bindPopup(popup_d33e9c7dc462d3d4565b7bde0fde3539)
#         ;
#
#
#
#
#             var circle_marker_62999e218e60bd224523adf35293934d = L.circleMarker(
#                 [38.9128, 29.1157],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#             var marker_7b2666e7bcb20d8e3520b47468453b62 = L.marker(
#                 [39.1863, 27.742],
#                 {}
#             ).addTo(map_8679f1bb0dbdaaba5ca7c70368aaecbe);
#
#
#         var popup_21fb12ef36d51aada5b7c3817becc807 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d8a6430d18dca71ed9e509d610c6bfe6 = $(`&lt;div id=&quot;html_d8a6430d18dca71ed9e509d610c6bfe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAYAT-SOMA (MANISA)&lt;/div&gt;`)[0];
#             popup_21fb12ef36d51aada5b7c3817becc807.setContent(html_d8a6430d18dca71ed9e509d610c6bfe6);
#
#
#         marker_7b2666e7bcb20d8e3520b47468453b62.bindPopup(popup_21fb12ef36d51aada5b7c3817becc807)
#         ;
#
#
#
#
#             var circle_marker_baf134d5ce88c9628f8c509de789aac2 = L.circleMarker(
#                 [39.1863, 27.742],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map

# %%
m= folium.Map([36,33], zoom_start=8,width='%100',height='%100')
location=df[["Enlem","Boylam"]]
plugins.MarkerCluster(location).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e1b6d1aec88a8ded0745591bc9b90bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e1b6d1aec88a8ded0745591bc9b90bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0e1b6d1aec88a8ded0745591bc9b90bd = L.map(
#                 &quot;map_0e1b6d1aec88a8ded0745591bc9b90bd&quot;,
#                 {
#                     center: [36.0, 33.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99c1765adc4b676437609ced817b267b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e1b6d1aec88a8ded0745591bc9b90bd);
#
#
#             var marker_cluster_fef34f2c00d84104ed43de1c164994af = L.markerClusterGroup(
#                 {}
#             );
#             map_0e1b6d1aec88a8ded0745591bc9b90bd.addLayer(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_5c787bf34b5ccc515881c1fe4e5a78fa = L.marker(
#                 [39.692, 41.8028],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_955489677f48f7f258fae656e437efd1 = L.marker(
#                 [36.008, 27.2592],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_92c4781b6edcfdc42b37e8ad412edccb = L.marker(
#                 [39.4707, 29.2163],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_dd0b4905651fdd261510ccaa332c7543 = L.marker(
#                 [39.7232, 30.7905],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_0a6a2129988410dc48d639490084ede3 = L.marker(
#                 [36.2265, 33.7438],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_d4f79bca988256e569b39456a2c575e9 = L.marker(
#                 [39.7287, 30.1263],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_eb99a2d91df85903e067320a64a0fb2b = L.marker(
#                 [38.9128, 29.1157],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_df945a4e8478da818ddf80741cb60a2c = L.marker(
#                 [39.1863, 27.742],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker_6c90e4e32b78d390d9ca87b84b436903 = L.marker(
#                 [38.573, 39.578],
#                 {}
#             ).addTo(marker_cluster_fef34f2c00d84104ed43de1c164994af);
#
#
#             var marker